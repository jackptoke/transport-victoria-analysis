# %%
# %sql
DROP TABLE IF EXISTS transport_vic_dev.`01_bronze`.bronze_vline_trip_updates;
DROP TABLE IF EXISTS transport_vic_dev.`02_silver`.trip_updates;
# Out:
# DataFrame[]

# %%
dbutils.widgets.text("catalog", "transport_vic_dev")
catalog = dbutils.widgets.get("catalog")

dbutils.fs.rm(f"/Volumes/{catalog}/01_bronze/_checkpoints/bronze_vline_trip_updates", True)
dbutils.fs.rm(f"/Volumes/{catalog}/02_silver/_checkpoints/trip_updates", True)
