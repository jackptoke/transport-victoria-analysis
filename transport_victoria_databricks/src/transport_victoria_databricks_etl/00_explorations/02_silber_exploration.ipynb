# %%
# %sql

SELECT * FROM transport_vic_dev.02_silver.trip_updates LIMIT 10;
# Out:
# DataFrame[feed_ts: timestamp, entity_id: string, trip_id: string, route_id: string, start_date: date, start_time: string, trip_rel: string, stop_sequence: int, stop_id: string, arrival_time: timestamp, arrival_delay_sec: int, departure_time: timestamp, departure_delay_sec: int, stop_rel: string, event_time: timestamp, source_file: string, _ingest_ts: timestamp, _silver_ts: timestamp]
